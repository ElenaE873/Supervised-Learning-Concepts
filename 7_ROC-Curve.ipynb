# %% [markdown]
# ### ROC

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  - set of points we get when trying all possible thresholds is called the **ROC Curve** L
#      - Rreceiver Operating Characteristic curve"

# %%
from sklearn.metrics import roc_curve
y_pred_prob = logreg.predict_proba(X_test)[:,1]

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# %% [markdown]
# #### plot

# %%
plt.plot([0,1], [0,1], 'k--')

plt.plot(fpr, tpr, label='Logistic Regression')

plt.xlabel('Flase Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Logistic Regression ROC Curve')

plt.show()

# %% [markdown]
# ### Area under the ROC Curve

# %% [markdown]
# - Larger area under the curve the better the model

# %%
#follows the same approach as the KNN modeling
#1 - import
from sklearn.metrics import roc_auc_score
#2 instantiate the model instance
#3 - split test/train
#4 - fit to the training split
#5 - predict on the test X_test

roc_auc_score(y_test, y_pred_prob) #from above

# %% [markdown]
# ### Calculate AUC using Cross-Validation

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(logreg, X, y, cv=5, scoring='roc_auc')
print(cv_scores)
